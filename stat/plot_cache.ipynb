# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("./measure_filecache_rst.txt")
x = data[:,0]
y = data[:,1]

plt.plot(x, y)
plt.xlabel("FileSize (GB)")
plt.ylabel("ReadTime (Cycles)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/winter/Desktop/CSE 221/project/stat/plot_cache.ipynb Cell 2 in 7
#       <a href='vscode-notebook-cell:/Users/winter/Desktop/CSE%20221/project/stat/plot_cache.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> plt.plot(x, y)
#       <a href='vscode-notebook-cell:/Users/winter/Desktop/CSE%20221/project/stat/plot_cache.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> plt.xlabel("FileSize (GB)")
# ----> <a href='vscode-notebook-cell:/Users/winter/Desktop/CSE%20221/project/stat/plot_cache.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> plt.set_ylabel("ReadTime (Cycles)")
#       <a href='vscode-notebook-cell:/Users/winter/Desktop/CSE%20221/project/stat/plot_cache.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_ylabel'
